# %%
import temporian as tp

# %%
a = tp.event_set([1,2,3], {"f1":["A","B","A"] })

a.simple_moving_average(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 a = tp.event_set([1,2,3], {"f1":["A","B","A"] })
# ----> 3 a.simple_moving_average(2)
#
# File /mnt/f/projects/work/temporian/build_package/temporian/core/event_set_ops.py:2552, in EventSetOperations.simple_moving_average(self, window_length, sampling)
#    2500 """Computes the average of values in a sliding window over an
#    2501 [`EventSet`][temporian.EventSet].
#    2502
#    (...)
#    2546     EventSet containing the moving average of each feature in the input.
#    2547 """
#    2548 from temporian.core.operators.window.simple_moving_average import (
#    2549     simple_moving_average,
#    2550 )
# -> 2552 return simple_moving_average(
#    2553     self, window_length=window_length, sampling=sampling
#    2554 )
#
# ...
