# %%
# %pip install temporian -q
# Out:
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import temporian as tp

# %%
evset = tp.from_csv('test_data.csv')
evset = evset.set_index(['machine', 'label'])
evset
# Out:
# WARNING:root:Feature "machine" is an array of numpy.object_ and was casted to numpy.string_ (Note: numpy.string_ is equivalent to numpy.bytes_).
# indexes: [('machine', str_), ('label', int64)]
# features: [('f0', float64), ('f1', float64), ('f2', float64), ('f3', float64), ('f4', float64), ('f5', float64), ('f6', float64), ('f7', float64), ('f8', float64), ('f9', float64), ('f10', float64), ('f11', float64), ('f12', float64), ('f13', float64), ('f14', float64), ('f15', float64), ('f16', float64), ('f17', float64), ('f18', float64), ('f19', float64), ('f20', float64), ('f21', float64), ('f22', float64), ('f23', float64), ('f24', float64), ('f25', float64), ('f26', float64), ('f27', float64), ('f28', float64), ('f29', float64), ('f30', float64), ('f31', float64), ('f32', float64), ('f33', float64), ('f34', float64), ('f35', float64), ('f36', float64), ('f37', float64)]
# events:
#     machine=b'machine-1-1' label=0 (25785 events):
# ...
